# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Load your dataset
df = pd.read_csv('Cleaned Data/gurgaon_properties_cleaned_v2.csv').drop_duplicates()

prof = ProfileReport(df, explorative=True)
prof.to_file('output_report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/23 [00:00<?, ?it/s]
#   4%|▍         | 1/23 [00:00<00:08,  2.51it/s]
#  30%|███       | 7/23 [00:00<00:00, 16.48it/s]
#  52%|█████▏    | 12/23 [00:00<00:00, 23.36it/s]
# 100%|██████████| 23/23 [00:00<00:00, 30.06it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install pandas-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: pandas-profiling in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (3.2.0)
# Requirement already satisfied: joblib~=1.1.0 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from pandas-profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from pandas-profiling) (2.3.3)
# Requirement already satisfied: matplotlib>=3.2.0 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from pandas-profiling) (3.10.0)
# Requirement already satisfied: pydantic>=1.8.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas-profiling) (2.12.4)
# Requirement already satisfied: PyYAML>=5.0.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas-profiling) (6.0.3)
# Requirement already satisfied: jinja2>=2.11.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas-profiling) (3.1.6)
# Requirement already satisfied: markupsafe~=2.1.1 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from pandas-profiling) (2.1.5)
# Requirement already satisfied: visions==0.7.4 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (0.7.4)
# Requirement already satisfied: numpy>=1.16.0 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from pandas-profiling) (2.3.5)
# Requirement already satisfied: htmlmin>=0.1.12 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from pandas-profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from pandas-profiling) (0.12.5)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas-profiling) (2.32.5)
# Requirement already satisfied: tqdm>=4.48.2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas-profiling) (4.67.1)
# Requirement already satisfied: seaborn>=0.10.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas-profiling) (0.13.2)
# Requirement already satisfied: multimethod>=1.4 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from pandas-profiling) (1.12)
# Requirement already satisfied: attrs>=19.3.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (3.5)
# Requirement already satisfied: imagehash in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.2)
# Requirement already satisfied: Pillow in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (12.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pydantic>=1.8.1->pandas-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pydantic>=1.8.1->pandas-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pydantic>=1.8.1->pandas-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pydantic>=1.8.1->pandas-profiling) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests>=2.24.0->pandas-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests>=2.24.0->pandas-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from requests>=2.24.0->pandas-profiling) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from requests>=2.24.0->pandas-profiling) (2026.2.25)
# Requirement already satisfied: PyWavelets in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.9.0)

# %%
pip install numba==0.56.4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Collecting numba==0.56.4
#   Using cached numba-0.56.4.tar.gz (2.4 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [23 lines of output]
#       /tmp/pip-install-5flgipg_/numba_b19102eebc0547f38235d1086f63b2e0/versioneer.py:415: SyntaxWarning: invalid escape sequence '\s'
#         mo = re.search(r'=\s*"(.*)"', line)
#       Traceback (most recent call last):
#         File "/opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 389, in <module>
#           main()
#         File "/opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 143, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-peqw6kzl/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 333, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-peqw6kzl/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#         File "/tmp/pip-build-env-peqw6kzl/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 520, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "/tmp/pip-build-env-peqw6kzl/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 317, in run_setup
#           exec(code, locals())
#         File "<string>", line 51, in <module>
#         File "<string>", line 48, in _guard_py_ver
#       RuntimeError: Cannot install on Python version 3.12.12; only versions >=3.7,<3.11 are supported.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'numba' when getting requirements to build wheel
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ydata-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: ydata-profiling in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (4.18.0)
# Requirement already satisfied: scipy<1.17,>=1.8 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from ydata-profiling) (2.12.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from ydata-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Using cached visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.4,>=1.22 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from ydata-profiling) (2.3.5)
# Requirement already satisfied: minify-html>=0.15.0 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from ydata-profiling) (0.18.1)
# Collecting filetype>=1.0.0 (from ydata-profiling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: phik<0.13,>=0.12.5 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from ydata-profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=4 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from ydata-profiling) (4.4.4)
# Requirement already satisfied: imagehash==4.3.2 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from ydata-profiling) (1.9.5)
# Requirement already satisfied: dacite<2,>=1.9 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from imagehash==4.3.2->ydata-profiling) (12.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.2.25)
# Requirement already satisfied: patsy>=0.5.6 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: attrs>=19.3.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.5)
# Requirement already satisfied: puremagic in /home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Using cached visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: filetype, visions
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [filetype]  WARNING: The script filetype is installed in '/home/92c768db-2d10-4625-b98b-4fad701a5f90/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4━━━━ 0/2 [filetype]
#     Uninstalling visions-0.7.4:━━━╺━━━━━━━━━━━━━━━━━━━ 1/2 [visions]
#       Successfully uninstalled visions-0.7.4m╺━━━━━━━━━━━━━━━━━━━ 1/2 [visions]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [visions]━━━━ 1/2 [visions]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.8.1 which is incompatible.
# Successfully installed filetype-1.2.0 visions-0.8.1
# Note: you may need to restart the kernel to use updated packages.
